# %% [markdown]
# ### API CONNECTION

# %%
#importa librerias
import pandas as pd
import requests
import json
import psycopg2
from sqlalchemy import create_engine

# %%
# Leer la API key desde el archivo de texto
with open("key.txt",'r') as f:
    pwd= f.read()

# %%
# URL de la API
url = 'https://opendata.aemet.es/opendata/api/observacion/convencional/todas'

# Parametros de la solicitud GET
params = {"api_key": pwd}

# Realiza la solicitud GET a la API
response = requests.get(url, params=params)

# Verifica si la solicitud fue exitosa
if response.status_code == 200:
    try:
        # Obtiene la URL de los datos reales del diccionario de respuesta
        data_url = response.json().get('datos')
        metadatos_url = response.json().get('metadatos')
        
        # Realiza una solicitud GET a la URL de los datos reales
        response_data = requests.get(data_url)
        response_metadatos  = requests.get(metadatos_url)
        
        # Carga los datos en un DataFrame si la solicitud fue exitosa
        if response_data.status_code == 200:
            # Obtiene los datos en formato JSON
            data_json = response_data.json()
            
            # Convierte los datos a un DataFrame de Pandas
            df = pd.DataFrame(data_json)
            
        else:
            print("Error al obtener los datos reales:", response_data.status_code)
    except Exception as e:
        print("Error al procesar la respuesta:", e)
else:
    print("Error al obtener la URL de los datos:", response.status_code)

# %% [markdown]
# ### COLUMN SELECTION

# %%
# Obtiene la URL de los datos reales del diccionario de respuesta
metadatos_json = response_metadatos.json()
# Convierte los datos a un DataFrame de Pandas
df_aux = pd.DataFrame(metadatos_json)
# Imprime resultados del df
df_aux.head()
# Out:
#          unidad_generadora   periodicidad           formato  \
# 0  Servicio de Observación  continuamente  application/json
# 1  Servicio de Observación  continuamente  application/json
# 2  Servicio de Observación  continuamente  application/json
# 3  Servicio de Observación  continuamente  application/json
# 4  Servicio de Observación  continuamente  application/json
#
#                                            copyright  \
# 0  © AEMET. Autorizado el uso de la información y...
# 1  © AEMET. Autorizado el uso de la información y...
# 2  © AEMET. Autorizado el uso de la información y...
# 3  © AEMET. Autorizado el uso de la información y...
# 4  © AEMET. Autorizado el uso de la información y...
#
#                             notaLegal  \
# 0  https://www.aemet.es/es/nota_legal
# 1  https://www.aemet.es/es/nota_legal
# 2  https://www.aemet.es/es/nota_legal
# 3  https://www.aemet.es/es/nota_legal
# 4  https://www.aemet.es/es/nota_legal
#
#                                               campos
# 0  {'id': 'idema', 'descripcion': 'Indicativo cli...
# 1  {'id': 'lon', 'descripcion': 'Longitud de la e...
# 2  {'id': 'lat', 'descripcion': 'Latitud de la es...
# 3  {'id': 'alt', 'descripcion': 'Altitud de la es...
# 4  {'id': 'ubi', 'descripcion': 'Ubicación de la ...

# %%
# Normaliza la columna "campos" del diccionario JSON para entender la metadata
df_normalized = pd.json_normalize(df_aux['campos'])

# Imprime resultados
df_normalized
# Out:
#            id                                        descripcion  \
# 0       idema  Indicativo climatógico de la estación meteorol...
# 1         lon     Longitud de la estación meteorológica (grados)
# 2         lat      Latitud de la estación meteorológica (grados)
# 3         alt                   Altitud de la estación en metros
# 4         ubi    Ubicación de la estación. Nombre de la estación
# 5        fint  Fecha hora final del período de observación, s...
# 6        prec  Precipitación acumulada, medida por el pluvióm...
# 7      pacutp  Precipitación acumulada, medida por el disdróm...
# 8      pliqtp  Precipitación líquida acumulada durante los 60...
# 9       psolt  Precipitación sólida acumulada durante los 60 ...
# 10       vmax  Velocidad máxima del viento, valor máximo del ...
# 11         vv  Velocidad media del viento, media escalar de l...
# 12      vmaxu  Velocidad máxima del viento (sensor ultrasónic...
# 13        vvu  Velocidad media del viento (sensor ultrasónico...
# 14         dv  Dirección media del viento, en el período de 1...
# 15        dvu  Dirección media del viento (sensor ultrasónico...
# 16       dmax  Dirección del viento máximo registrado en los ...
# 17      dmaxu  Dirección del viento máximo registrado en los ...
# 18      stdvv  Desviación estándar de las muestras adquiridas...
# 19      stddv  Desviación estándar de las muestras adquiridas...
# 20     stdvvu  Desviación estándar de las muestras adquiridas...
# 21     stddvu  Desviación estándar de las muestras adquiridas...
# 22         hr  Humedad relativa instantánea del aire correspo...
# 23       inso  Duración de la insolación durante los 60 minut...
# 24       pres  Presión instantánea al nivel en el que se encu...
# 25  pres_nmar  Valor de la presión reducido al nivel del mar ...
# 26         ts  Temperatura suelo, temperatura instantánea jun...
# 27    tss20cm  Temperatura subsuelo 20 cm, temperatura del su...
# 28     tss5cm  Temperatura subsuelo 5 cm, temperatura del sub...
# 29         ta  Temperatura instantánea del aire correspondien...
# 30        tpr  Temperatura del punto de rocío calculado corre...
# 31      tamin  Temperatura mínima del aire, valor mínimo de l...
# 32      tamax  Temperatura máxima del aire, valor máximo de l...
# 33        vis  Visibilidad, promedio de la medida de la visib...
# 34     geo700  Altura del nivel de la superficie de referenci...
# 35     geo850  Altura del nivel de la superficie de referenci...
# 36     geo925  Altura del nivel de la superficie barométrica ...
# 37    rviento  Recorrido del viento durante los 60 minutos an...
# 38      nieve  Espesor de la capa de nieve medid en los 10 mi...
#
#                       tipo_datos  requerido
# 0                         string       True
# 1                          float       True
# 2                          float       True
# 3                          float       True
# 4                         string       True
# 5   string (AAAA-MM-DDTHH:MM:SS)      False
# 6                          float      False
# 7                          float      False
# 8                          float      False
# 9                          float      False
# 10                         float      False
# 11                         float      False
# 12                         float      False
# 13                         float      False
# 14                         float      False
# 15                         float      False
# 16                         float      False
# 17                         float      False
# 18                         float      False
# 19                         float      False
# 20                         float      False
# 21                         float      False
# 22                         float      False
# 23                         float      False
# 24                         float      False
# 25                         float      False
# 26                         float      False
# 27                         float      False
# 28                         float      False
# 29                         float      False
# 30                         float      False
# 31                         float      False
# 32                         float      False
# 33                         float      False
# 34                         float      False
# 35                         float      False
# 36                         float      False
# 37                         float      False
# 38                         float      False

# %%
# Selecciona columnas deseadas para el dataframe final
columnas_seleccionadas = ['ubi','lon', 'lat','alt','fint', 'prec', 'hr', 'ta', 'tamin', 'tamax']
df_final = df[columnas_seleccionadas]
df_final
# Out:
#                                         ubi        lon        lat     alt  \
# 0                                   ALFORJA   0.963335  41.213894   406.0
# 1                           REUS/AEROPUERTO   1.178894  41.149720    71.0
# 2                                     VALLS   1.260838  41.293053   233.0
# 3                 TARRAGONA  FAC. GEOGRAFIA   1.249167  41.123894    55.0
# 4                                   PONTONS   1.519269  41.417053   632.0
# ...                                     ...        ...        ...     ...
# 19155  LAS PALMAS DE GC. PLAZA  DE LA FERIA -15.421389  28.113056    15.0
# 19156                            MASPALOMAS -15.595833  27.735832     6.0
# 19157        TEGUISE LA GRACIOSA-HELIPUERTO -13.510210  29.229586    19.0
# 19158           SAN ANDRÉS-DEPÓSITO CABILDO -17.960417  27.768951  1070.0
# 19159                  EL HIERRO/AEROPUERTO -17.888890  27.818888    32.0
#
#                       fint  prec    hr    ta  tamin  tamax
# 0      2024-03-10T18:00:00   0.0  86.0   7.5    7.5    8.6
# 1      2024-03-10T18:00:00   0.9  77.0  10.2   10.0   12.0
# 2      2024-03-10T18:00:00   0.0  73.0  11.3   11.3   12.1
# 3      2024-03-10T18:00:00   0.6  71.0  11.7   11.7   13.2
# 4      2024-03-10T18:00:00   0.0  75.0   7.2    7.2    7.8
# ...                    ...   ...   ...   ...    ...    ...
# 19155  2024-03-11T17:00:00   0.0  78.0  19.2   19.2   19.8
# 19156  2024-03-11T17:00:00   0.0  69.0  20.3   20.3   21.1
# 19157  2024-03-11T17:00:00   0.0  51.0  19.4   19.3   20.5
# 19158  2024-03-11T17:00:00   0.0  77.0  13.0   12.7   13.2
# 19159  2024-03-11T17:00:00   0.0  67.0  20.4   20.3   21.1
#
# [19160 rows x 10 columns]

# %% [markdown]
# ### REDSHIFT CONNECTION

# %%
# Crea la conexión a Redshift
url="data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws.com"
data_base="data-engineer-database"
user="julietagsaez_coderhouse"
with open("redshift_key.txt",'r') as f:
    pwd_rd= f.read()
try:
    conn = psycopg2.connect(
        host='data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws.com',
        dbname=data_base,
        user=user,
        password=pwd_rd,
        port='5439'
    )
    print("Conectado a Redshift con éxito")
    
except Exception as e:
    print("Error al intentar conectar a Redshift")
    print(e)
# Out:
# Conectado a Redshift con éxito

# %%
# Crea la tabla en Redshift con el ID + columnas 
with conn.cursor() as cur:
    cur.execute("""
        CREATE TABLE IF NOT EXISTS julietagsaez_coderhouse.estaciones_metereologicas (
            id INT IDENTITY(1,1) PRIMARY KEY,
            ubicacion VARCHAR (50),
            longitud FLOAT,
            latitud FLOAT,
            altitud FLOAT, 
            fecha_obs VARCHAR(50), 
            precipitaciones FLOAT,
            humedad FLOAT,
            temperatura FLOAT, 
            temperatura_min FLOAT,
            temperatura_max FLOAT         
        )
    """)
    conn.commit()

# %%
# Trunca tabla para evitar errores
with conn.cursor() as cur:
  cur.execute("Truncate table estaciones_metereologicas")
  count = cur.rowcount

# %%
# Consulta la tabla
cur = conn.cursor()
cur.execute("SELECT * FROM estaciones_metereologicas")
resultados = cur.fetchall()
resultados
# Out:
# []

# %%
# Define el mapeo de columnas
column_mapping = {
    'ubi': 'ubicacion',
    'lon': 'longitud',
    'lat': 'latitud',
    'alt': 'altitud',
    'fint': 'fecha_obs',
    'prec': 'precipitaciones',
    'hr': 'humedad',
    'ta': 'temperatura',
    'tamin': 'temperatura_min',
    'tamax': 'temperatura_max'
}

# Aplica el mapeo de columnas al DataFrame
df_final_mapped = df_final.rename(columns=column_mapping)

df_final_mapped.head()
# Out:
#                    ubicacion  longitud    latitud  altitud  \
# 0                    ALFORJA  0.963335  41.213894    406.0
# 1            REUS/AEROPUERTO  1.178894  41.149720     71.0
# 2                      VALLS  1.260838  41.293053    233.0
# 3  TARRAGONA  FAC. GEOGRAFIA  1.249167  41.123894     55.0
# 4                    PONTONS  1.519269  41.417053    632.0
#
#              fecha_obs  precipitaciones  humedad  temperatura  \
# 0  2024-03-10T18:00:00              0.0     86.0          7.5
# 1  2024-03-10T18:00:00              0.9     77.0         10.2
# 2  2024-03-10T18:00:00              0.0     73.0         11.3
# 3  2024-03-10T18:00:00              0.6     71.0         11.7
# 4  2024-03-10T18:00:00              0.0     75.0          7.2
#
#    temperatura_min  temperatura_max
# 0              7.5              8.6
# 1             10.0             12.0
# 2             11.3             12.1
# 3             11.7             13.2
# 4              7.2              7.8

# %%
# Crea motor SQLAlchemy
engine = create_engine(f'postgresql+psycopg2://{user}:{pwd_rd}@{url}:{5439}/{data_base}')

# %%
# Carga DataFrame en la tabla de Redshift
df_final_mapped.to_sql('estaciones_metereologicas', engine, index=False, if_exists='replace')
